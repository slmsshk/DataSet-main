# %%
import pandas as pd

# %%
main = pd.read_csv('main.csv')
main.head()
# Out:
#                    event_id       event event_split event_region  \
# 0  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 1  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 2  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 3  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 4  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
#
#                                           event_slug  \
# 0  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 1  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 2  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 3  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 4  https://octane.gg/events/642d-rlcs-2021-22-fal...
#
#             event_start_date             event_end_date event_tier  \
# 0  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00  Qualifier
# 1  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00  Qualifier
# ...

# %%
rows,columns = main.shape

print(f"No of rows: {rows}\tNo Of columns: {columns}")
print(f"Size of the dataset: {main.size}")
columns = main.columns

print('Columns:', columns.to_list())
# Out:
# No of rows: 18740	No Of columns: 36
# Size of the dataset: 674640
# Columns: ['event_id', 'event', 'event_split', 'event_region', 'event_slug', 'event_start_date', 'event_end_date', 'event_tier', 'event_phase', 'prize_money', 'stage_step', 'stage', 'stage_start_date', 'stage_end_date', 'stage_is_lan', 'stage_is_qualifier', 'liquipedia_link', 'location_venue', 'location_city', 'location_country', 'match_id', 'match_slug', 'match_number', 'match_round', 'match_date', 'match_format', 'reverse_sweep_attempt', 'reverse_sweep', 'game_id', 'game_number', 'game_date', 'game_duration', 'map_id', 'map_name', 'overtime', 'ballchasing_id']

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18740 entries, 0 to 18739
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               18740 non-null  object
#  1   event                  18740 non-null  object
#  2   event_split            18740 non-null  object
#  3   event_region           18740 non-null  object
#  4   event_slug             18740 non-null  object
#  5   event_start_date       18740 non-null  object
#  6   event_end_date         18740 non-null  object
#  7   event_tier             18740 non-null  object
#  8   event_phase            18740 non-null  object
#  9   prize_money            18740 non-null  float64
#  10  stage_step             18740 non-null  int64
#  11  stage                  18740 non-null  object
#  12  stage_start_date       18740 non-null  object
#  13  stage_end_date         18740 non-null  object
# ...

# %%
import matplotlib.pyplot as plt

int_columns = main.select_dtypes(int)
float_columns = main.select_dtypes(float)
numeric_columns = pd.concat([int_columns,float_columns],axis=1)

pd.plotting.scatter_matrix(numeric_columns)

plt.show()

# %%
pd.plotting.scatter_matrix(main.select_dtypes(float))
# Out:
# array([[<Axes: xlabel='prize_money', ylabel='prize_money'>,
#         <Axes: xlabel='game_number', ylabel='prize_money'>,
#         <Axes: xlabel='game_duration', ylabel='prize_money'>],
#        [<Axes: xlabel='prize_money', ylabel='game_number'>,
#         <Axes: xlabel='game_number', ylabel='game_number'>,
#         <Axes: xlabel='game_duration', ylabel='game_number'>],
#        [<Axes: xlabel='prize_money', ylabel='game_duration'>,
#         <Axes: xlabel='game_number', ylabel='game_duration'>,
#         <Axes: xlabel='game_duration', ylabel='game_duration'>]],
#       dtype=object)

# %%
# Generate the synthetic data without scaling
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=10000, n_features=4, random_state=42)

# Create DataFrames for input and output
input_df = pd.DataFrame(data=X, columns=['Age', 'Weight', 'Expertise', 'Speed'])
output_df = pd.DataFrame(data=y, columns=['Accuracy'])


complete = pd.concat([input_df,output_df],axis=1)

pd.plotting.scatter_matrix(complete)
plt.show()

# %%
import seaborn as sns

corr = complete.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X = complete['Age']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

x_train,x_test,y_train,y_test =train_test_split(input_df,output_df,test_size=.20,random_state=40)

lr = LinearRegression()
lr.fit(x_train,y_train)

pred = lr.predict(x_test)
print(f'MSE: {int(mean_squared_error(y_test,pred))}')
# Out:
# MSE: 0

# %%
import random
data = [i for i in range(100)]
X,Y= [],[]
end =3
for i in range(len(data)):
    if end>=len(data):break
    X.append(data[i:end])
    Y.append(data[end])
    end+=1
    
X[-1],Y[-1]
# Out:
# ([96, 97, 98], 99)

# %%
pd.plotting.scatter_matrix(pd.DataFrame(X,Y))
# Out:
# array([[<Axes: xlabel='0', ylabel='0'>, <Axes: xlabel='1', ylabel='0'>,
#         <Axes: xlabel='2', ylabel='0'>],
#        [<Axes: xlabel='0', ylabel='1'>, <Axes: xlabel='1', ylabel='1'>,
#         <Axes: xlabel='2', ylabel='1'>],
#        [<Axes: xlabel='0', ylabel='2'>, <Axes: xlabel='1', ylabel='2'>,
#         <Axes: xlabel='2', ylabel='2'>]], dtype=object)

# %%
import numpy as np

x_ar,y_ar = np.array(X),np.array(Y)


x_train,x_test,y_train,y_test =train_test_split(x_ar,y_ar,test_size=.20,random_state=40)

lr = LinearRegression()
lr.fit(x_train,y_train)

pred = lr.predict(x_test)
print(f'MSE: {int(mean_squared_error(y_test,pred))}')
# Out:
# MSE: 868

# %%
un = np.array([[1001,1002,1003]])
lr.predict(un)
# Out:
# array([1004.])
