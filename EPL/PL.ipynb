# %%
import pandas as pd

# %%
s_1516 = pd.read_csv('season-1516_csv.csv')
s_1617 = pd.read_csv('season-1617_csv.csv')

# %% [markdown]
# <div style="width: 1024px; height: 250px; line-height: em; overflow:scroll;  padding: 5px;">
# <table>
# <thead>
#  <tr>
#    <th>Field Name</th>
#    <th>Order</th>
#    <th>Type (Format)</th>
#    <th>Description</th>
#  </tr>
# </thead>
# <tbody>
#
#  <tr>
#    <th>Div</th>
#    <td>1</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>Date</th>
#    <td>2</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HomeTeam</th>
#    <td>3</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AwayTeam</th>
#    <td>4</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>FTHG</th>
#    <td>5</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>FTAG</th>
#    <td>6</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>FTR</th>
#    <td>7</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HTHG</th>
#    <td>8</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HTAG</th>
#    <td>9</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HTR</th>
#    <td>10</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>Referee</th>
#    <td>11</td>
#    <td class="type type-string">string (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HS</th>
#    <td>12</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AS</th>
#    <td>13</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HST</th>
#    <td>14</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AST</th>
#    <td>15</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HF</th>
#    <td>16</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AF</th>
#    <td>17</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HC</th>
#    <td>18</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AC</th>
#    <td>19</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HY</th>
#    <td>20</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AY</th>
#    <td>21</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>HR</th>
#    <td>22</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>AR</th>
#    <td>23</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>B365H</th>
#    <td>24</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>B365D</th>
#    <td>25</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>B365A</th>
#    <td>26</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BWH</th>
#    <td>27</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BWD</th>
#    <td>28</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BWA</th>
#    <td>29</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>IWH</th>
#    <td>30</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>IWD</th>
#    <td>31</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>IWA</th>
#    <td>32</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSH</th>
#    <td>33</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSD</th>
#    <td>34</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSA</th>
#    <td>35</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>WHH</th>
#    <td>36</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>WHD</th>
#    <td>37</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>WHA</th>
#    <td>38</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>VCH</th>
#    <td>39</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>VCD</th>
#    <td>40</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>VCA</th>
#    <td>41</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>Bb1X2</th>
#    <td>42</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMxH</th>
#    <td>43</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAvH</th>
#    <td>44</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMxD</th>
#    <td>45</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAvD</th>
#    <td>46</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMxA</th>
#    <td>47</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAvA</th>
#    <td>48</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbOU</th>
#    <td>49</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMx&gt;2.5</th>
#    <td>50</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAv&gt;2.5</th>
#    <td>51</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMx&lt;2.5</th>
#    <td>52</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAv&lt;2.5</th>
#    <td>53</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAH</th>
#    <td>54</td>
#    <td class="type type-integer">integer (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAHh</th>
#    <td>55</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMxAHH</th>
#    <td>56</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAvAHH</th>
#    <td>57</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbMxAHA</th>
#    <td>58</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>BbAvAHA</th>
#    <td>59</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSCH</th>
#    <td>60</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSCD</th>
#    <td>61</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
#  <tr>
#    <th>PSCA</th>
#    <td>62</td>
#    <td class="type type-number">number (default) </td>
#    <td></td>
#  </tr>
#
# </tbody>
# </table>
#     </div>

# %% [markdown]
# <div style="width: 1024px; height: 250px; line-height: em; overflow:scroll;  padding: 5px;">
#
# 1. **Div**: Division of the match (e.g., league name or tier).
# 2. **Date**: Date of the match.
# 3. **HomeTeam**: Name of the home team.
# 4. **AwayTeam**: Name of the away team.
# 5. **FTHG**: Full-time home team goals (integer).
# 6. **FTAG**: Full-time away team goals (integer).
# 7. **FTR**: Full-time result (win: 'H' for home, 'A' for away, 'D' for draw).
# 8. **HTHG**: Half-time home team goals (integer).
# 9. **HTAG**: Half-time away team goals (integer).
# 10. **HTR**: Half-time result (win: 'H' for home, 'A' for away, 'D' for draw).
# 11. **Referee**: Name of the referee.
# 12. **HS**: Home team shots (integer).
# 13. **AS**: Away team shots (integer).
# 14. **HST**: Home team shots on target (integer).
# 15. **AST**: Away team shots on target (integer).
# 16. **HF**: Home team fouls committed (integer).
# 17. **AF**: Away team fouls committed (integer).
# 18. **HC**: Home team corners (integer).
# 19. **AC**: Away team corners (integer).
# 20. **HY**: Home team yellow cards (integer).
# 21. **AY**: Away team yellow cards (integer).
# 22. **HR**: Home team red cards (integer).
# 23. **AR**: Away team red cards (integer).
# 24. **B365H**: Betting odds for home team to win (number).
# 25. **B365D**: Betting odds for draw (number).
# 26. **B365A**: Betting odds for away team to win (number).
# 27. **BWH**: Betting odds for home team to win (number).
# 28. **BWD**: Betting odds for draw (number).
# 29. **BWA**: Betting odds for away team to win (number).
# 30. **IWH**: Betting odds for home team to win (number).
# 31. **IWD**: Betting odds for draw (number).
# 32. **IWA**: Betting odds for away team to win (number).
# 33. **PSH**: Betting odds for home team to win (number).
# 34. **PSD**: Betting odds for draw (number).
# 35. **PSA**: Betting odds for away team to win (number).
# 36. **WHH**: Betting odds for home team to win (number).
# 37. **WHD**: Betting odds for draw (number).
# 38. **WHA**: Betting odds for away team to win (number).
# 39. **VCH**: Betting odds for home team to win (number).
# 40. **VCD**: Betting odds for draw (number).
# 41. **VCA**: Betting odds for away team to win (number).
# 42. **Bb1X2**: Number of bookmakers offering 1X2 odds (integer).
# 43. **BbMxH**: Maximum home team odds offered by bookmakers (number).
# 44. **BbAvH**: Average home team odds offered by bookmakers (number).
# 45. **BbMxD**: Maximum draw odds offered by bookmakers (number).
# 46. **BbAvD**: Average draw odds offered by bookmakers (number).
# 47. **BbMxA**: Maximum away team odds offered by bookmakers (number).
# 48. **BbAvA**: Average away team odds offered by bookmakers (number).
# 49. **BbOU**: Number of bookmakers offering over/under odds (integer).
# 50. **BbMx>2.5**: Maximum over 2.5 goals odds offered by bookmakers (number).
# 51. **BbAv>2.5**: Average over 2.5 goals odds offered by bookmakers (number).
# 52. **BbMx<2.5**: Maximum under 2.5 goals odds offered by bookmakers (number).
# 53. **BbAv<2.5**: Average under 2.5 goals odds offered by bookmakers (number).
# 54. **BbAH**: Number of bookmakers offering Asian handicap odds (integer).
# 55. **BbAHh**: Asian handicap for home team (number).
# 56. **BbMxAHH**: Maximum Asian handicap home team odds offered by bookmakers (number).
# 57. **BbAvAHH**: Average Asian handicap home team odds offered by bookmakers (number).
# 58. **BbMxAHA**: Maximum Asian handicap away team odds offered by bookmakers (number).
# 59. **BbAvAHA**: Average Asian handicap away team odds offered by bookmakers (number).
# 60. **PSCH**: Betting odds for home team to win according to Pinnacle Sports (number).
# 61. **PSCD**: Betting odds for draw according to Pinnacle Sports (number).
# 62. **PSCA**: Betting odds for away team to win according to Pinnacle Sports (number).

# %%
pd.set_option('display.max_columns',None)
complete = pd.concat([s_1516,s_1617])
complete.head()
# Out:
#   Div      Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  08/08/15  Bournemouth  Aston Villa     0     1   A     0     0   D
# 1  E0  08/08/15      Chelsea      Swansea     2     2   D     2     1   H
# 2  E0  08/08/15      Everton      Watford     2     2   D     0     1   A
# 3  E0  08/08/15    Leicester   Sunderland     4     2   H     3     0   H
# 4  E0  08/08/15   Man United    Tottenham     1     0   H     1     0   H
#
#          Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0  M Clattenburg  11   7    2    3  13  13   6   3   3   4   0   0   2.00
# 1       M Oliver  11  18    3   10  15  16   4   8   1   3   1   0   1.36
# 2        M Jones  10  11    5    5   7  13   8   2   1   2   0   0   1.70
# 3        L Mason  19  10    8    5  13  17   6   3   2   4   0   0   1.95
# 4         J Moss   9   9    1    4  12  12   1   2   2   3   0   0   1.65
#
#    B365D  B365A   BWH   BWD   BWA   IWH  IWD  IWA   LBH  LBD   LBA   PSH  \
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(complete)
profile.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\Slmss\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:84: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   return _cramers_corrected_stat(pd.crosstab(col_1, col_2), correction=True)
# C:\Users\Slmss\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
teams = complete[['HomeTeam','AwayTeam']]
l1,l2 = complete.HomeTeam.to_list(),complete.AwayTeam.to_list()

# %%
help(list.extend)
# Out:
# Help on method_descriptor:
#
# extend(self, iterable, /)
#     Extend list by appending elements from the iterable.

# %%
l1.extend(l2)
l1
# Out:
# ['Bournemouth',
#  'Chelsea',
#  'Everton',
#  'Leicester',
#  'Man United',
#  'Norwich',
#  'Arsenal',
#  'Newcastle',
#  'Stoke',
#  'West Brom',
#  'Aston Villa',
#  'Southampton',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Watford',
#  'West Ham',
#  'Crystal Palace',
#  'Man City',
#  'Liverpool',
#  'Crystal Palace',
#  'Leicester',
#  'Man United',
#  'Norwich',
#  'Sunderland',
#  'West Ham',
#  'Everton',
#  'Watford',
#  'West Brom',
#  'Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Chelsea',
#  'Liverpool',
#  'Man City',
#  'Newcastle',
#  'Stoke',
#  'Tottenham',
#  'Southampton',
#  'Swansea',
#  'Arsenal',
#  'Crystal Palace',
#  'Everton',
#  'Man United',
#  'Norwich',
#  'Watford',
#  'West Brom',
#  'Leicester',
#  'Sunderland',
#  'West Ham',
#  'Aston Villa',
#  'Bournemouth',
#  'Chelsea',
#  'Man City',
#  'Newcastle',
#  'Stoke',
#  'Swansea',
#  'Liverpool',
#  'Southampton',
#  'Tottenham',
#  'Leicester',
#  'Liverpool',
#  'Man United',
# ...

# %%
total_Teams = set(l1)
print('All Teams: ',total_Teams)
print('Count: ',len(total_Teams))
# Out:
# All Teams:  {'Aston Villa', 'Watford', 'Burnley', 'Swansea', 'Hull', 'Southampton', 'Man United', 'Liverpool', 'Tottenham', 'Man City', 'Norwich', 'Everton', 'Bournemouth', 'Stoke', 'Newcastle', 'Leicester', 'Middlesbrough', 'West Brom', 'West Ham', 'Arsenal', 'Chelsea', 'Sunderland', 'Crystal Palace'}
# Count:  23

# %%
l1,l2
# Out:
# (['Bournemouth',
#   'Chelsea',
#   'Everton',
#   'Leicester',
#   'Man United',
#   'Norwich',
#   'Arsenal',
#   'Newcastle',
#   'Stoke',
#   'West Brom',
#   'Aston Villa',
#   'Southampton',
#   'Sunderland',
#   'Swansea',
#   'Tottenham',
#   'Watford',
#   'West Ham',
#   'Crystal Palace',
#   'Man City',
#   'Liverpool',
#   'Crystal Palace',
#   'Leicester',
#   'Man United',
#   'Norwich',
#   'Sunderland',
#   'West Ham',
#   'Everton',
#   'Watford',
#   'West Brom',
#   'Arsenal',
#   'Aston Villa',
#   'Bournemouth',
#   'Chelsea',
#   'Liverpool',
#   'Man City',
#   'Newcastle',
#   'Stoke',
#   'Tottenham',
#   'Southampton',
#   'Swansea',
#   'Arsenal',
#   'Crystal Palace',
#   'Everton',
#   'Man United',
#   'Norwich',
#   'Watford',
#   'West Brom',
#   'Leicester',
#   'Sunderland',
#   'West Ham',
#   'Aston Villa',
#   'Bournemouth',
#   'Chelsea',
#   'Man City',
#   'Newcastle',
#   'Stoke',
#   'Swansea',
#   'Liverpool',
#   'Southampton',
# ...
